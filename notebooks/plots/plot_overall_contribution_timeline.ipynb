# %% [markdown]
# # Overall Contribution Timeline

# %%
import pandas as pd
import matplotlib.pyplot as plt

from prfiesta.analysis.plot import plot_overall_timeline

df = pd.read_parquet('../samples_data/kiran94.parquet')

# %%
figure, axes = plt.subplots(ncols=1, nrows=1, figsize=(12, 6))

plot_overall_timeline(df, ax=axes)
# Out:
# <Axes: title={'center': 'Overall Contributions'}, xlabel='year', ylabel='id'>
