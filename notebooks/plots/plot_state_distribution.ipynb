# %% [markdown]
# # State Distribution

# %%
import pandas as pd
import matplotlib.pyplot as plt

from prfiesta.analysis.plot import plot_state_distribution

df = pd.read_parquet('../samples_data/kiran94.parquet')

# %%
figure, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 6))

plot_state_distribution(df, ax=axes)
# Out:
# <Axes: title={'center': 'State Distribution'}, xlabel='state', ylabel='Count'>
