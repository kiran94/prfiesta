# %% [markdown]
# ## Conventional Commit Breakdown

# %%
import pandas as pd
import matplotlib.pyplot as plt

from prfiesta.analysis.plot import plot_conventional_commit_breakdown

df = pd.read_parquet('../samples_data/kiran94.parquet')

# %%
figure, axes = plt.subplots(ncols=1, nrows=1, figsize=(12, 6))

plot_conventional_commit_breakdown(df, ax=axes)
# Out:
# <Axes: title={'center': 'Conventional Commit Breakdown'}, xlabel='count', ylabel='repository_name'>
