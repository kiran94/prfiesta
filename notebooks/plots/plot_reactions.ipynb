# %% [markdown]
# # Reaction Distribution

# %%
import pandas as pd
import matplotlib.pyplot as plt

from prfiesta.analysis.plot import plot_reactions

df = pd.read_parquet('../samples_data/charliermarsh.parquet')

# %%
figure, axes = plt.subplots(ncols=1, nrows=1, figsize=(12, 6))

plot_reactions(df, ax=axes, threshold=10)
# Out:
# <Axes: title={'center': 'Reactions'}>
