# %% [markdown]
# # Author Associations Distribution

# %%
import pandas as pd

from prfiesta.analysis.plot import plot_author_associations

df = pd.read_parquet('../samples_data/kiran94.parquet')

# %%
plot_author_associations(df)
# Out:
# <Axes: title={'center': 'Author Associations'}, ylabel='count'>
