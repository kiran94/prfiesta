# %% [markdown]
# # Pull Request View

# %%
import pandas as pd

from prfiesta.analysis.view import view_pull_requests

df = pd.read_parquet('../samples_data/kiran94.parquet')

# %%
view_pull_requests(df, relative_dates=True, head=100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>number</th>
#       <th>title</th>
#       <th>repository_name</th>
#       <th>updated_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>758</td>
#       <td><a href="https://github.com/rockerBOO/awesome-neovim/pull/758">Add `kiran94/edit-markdown-table.nvim`</a></td>
#       <td>rockerBOO/awesome-neovim</td>
#       <td>2 weeks ago</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td><a href="https://github.com/kiran94/edit-markdown-table.nvim/pull/3">chore(readme): corrected typo</a></td>
#       <td>kiran94/edit-markdown-table.nvim</td>
#       <td>2 weeks ago</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td><a href="https://github.com/kiran94/edit-markdown-table.nvim/pull/2">fix(ci): updated permissions</a></td>
#       <td>kiran94/edit-markdown-table.nvim</td>
#       <td>2 weeks ago</td>
#     </tr>
#     <tr>
#       <td>1</td>
# ...
